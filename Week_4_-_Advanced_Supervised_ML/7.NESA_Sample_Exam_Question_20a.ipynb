# %% [markdown]
# # NESA Sample Examination Question 20a OOP Implementation

# %% [markdown]
# In the sample examination question 20a students are given a decision tree and asked to optimise it. In this notebook, you are to reverse engineer a dataset, train an OOP descision tree machine learning model and map a decsion tree to prove the answer to the question.

# %% [markdown]
# #### Step 1 - Import Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# #### Step 2: Extract A Training Dataset
#
# <details>
#     <summary><h5 style="display:inline">Tip: How to extract the data</h5></summary>
#
# 1. Look at the decsision tree provided
# 2. Back track from each leaf node (ground true label) to the root note to create training case
# 3. You should have as many training cases as their are leaf nodes.
# 4. Look at how the data has been prepared in step 2 and 3 of [5.OPP_Decision_Trees.ipynb](5.OPP_Decision_Trees.ipynb) use that as a template
# </details>

# %% [markdown]
# Comple this table with your Training data
#
# | X | X | X | X | Buy |
# | --- | --- | --- | --- | --- |
# |  |  |  |  |  |

# %% [markdown]
# #### Step 3: One Hot Encode The Data

# %%
# Feature variable


# Target, Leaf node or ground truth label variable


# Column names variable

# %% [markdown]
# #### Step 4: Instantiate a Decision Tree Classifier Object

# %% [markdown]
# #### Step 5: Fit the model

# %% [markdown]
# #### Step 6: Predict Values

# %% [markdown]
# #### Step 7: Evaluate The Model

# %% [markdown]
# #### Step 8: Visual The Model & Statisics

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['Not Buy','Buy'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('images/cat.png')
Image(graph.create_png())

# %% [markdown]
# #### Step 9: Compare the trained model to the NESA Sample Exam Marking Guidelines
#
# <img src="images\sample_answer.png" alt="NESA sample answer"/>
