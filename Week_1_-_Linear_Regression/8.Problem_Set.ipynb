# %% [markdown]
# # Problem Set
#
# Pratice what you learnt today with these problems.

# %%
# Run the dependencies before you begin
import numpy as np
import matplotlib.pyplot as plt
from utils_common import compute_model_output

plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# __1. In a markdown block and using md syntax, create a ordered list of 4 different features that could be used to predict house prices.__

# %% [markdown]
# __2. In a code block, convert the following table to a Python List, Numpy array and a Pandas dataframe.__
#
# | Student Number | Student Name | Result |
# | --- | --- | --- |
# | 1234 | Ben | 99 |
# | 1235 | Jess | 85 |
# | 1236 | Janet | 50 |
# | 1237 | Kevin | 62 |
# | 1238 | Nick | 41 |

# %% [markdown]
# __3. In a markdown block select and justify one of the three data structures for use in Machine Learning__

# %% [markdown]
# __4. In a markdown block outline the machine learning Linear Regression Algorythm__

# %% [markdown]
# __5. Adjust $m$ and $b$ to manually fit a Linear regression line with good intuition or fit__

# %%
x_train = np.array([[-4], [-8], [-10], [-12], [-14]])
y_train = np.array([1, 3, 5, 7, 9])

m = 0
b = 0

tmp_f_mb = compute_model_output(x_train, m, b,)

plt.plot(x_train, tmp_f_mb, c='b',label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
plt.show()

# %% [markdown]
# __6. Add a legend, title, Xaxis title and Yaxis title to the MatPlotLib in question 5.__

# %% [markdown]
# __7. Explain what the problem is with this Linear Regression model__

# %%
x_train = np.array([1, 1.5, 1.8, 2, 2.2])
y_train = np.array([[200], [250], [260], [280], [500]])


m = 200
b = 10

tmp_f_mb = compute_model_output(x_train, m, b,)

plt.plot(x_train, tmp_f_mb, c='b',label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
plt.show()

# %% [markdown]
# __8. In a markdown block explain what the issue is with this data set if it was used for Machine Learning__
#
# ```python
# x_train = np.array([1000, 1500, 1800, 2000, 2200])
# y_train = np.array([[200000], [250000], [260000], [280000], [500000]])
# ```
